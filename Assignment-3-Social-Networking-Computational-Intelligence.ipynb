# %% [markdown]
# # Assignment 3: Social Networking & Computational Intelligence
# # I have chosen option 2 for this assignment.

# %% [markdown]
# # Task 1 : A link to the data set
# https://www.kaggle.com/datasets/ashaychoudhary/social-media-and-entertainment-dataset

# %%
# Task 2: A detailed description of the data set

# Importing and loading the kaggle dataset downloaded
import pandas as pd

file_path = "social_media_entertainment_data.csv"
df = pd.read_csv(file_path)
df.head() # Displaying some of the row of the dataset
# Out:
#    User ID  Age  Gender  Country  Daily Social Media Time (hrs)  \
# 0        1   32   Other  Germany                           4.35
# 1        2   62   Other    India                           4.96
# 2        3   51  Female      USA                           6.78
# 3        4   44  Female    India                           5.06
# 4        5   21   Other  Germany                           2.57
#
#    Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                            4.08                            5
# 1                            4.21                            2
# 2                            1.77                            4
# 3                            9.21                            3
# 4                            1.30                            4
#
#   Primary Platform  Daily Messaging Time (hrs)  \
# 0           TikTok                        0.35
# 1          YouTube                        2.55
# 2         Facebook                        2.09
# ...

# %%
df.describe()
# Out:
#              User ID            Age  Daily Social Media Time (hrs)  \
# count  300000.000000  300000.000000                  300000.000000
# mean   150000.500000      38.530547                       4.254808
# std     86602.684716      15.005038                       2.165604
# min         1.000000      13.000000                       0.500000
# 25%     75000.750000      26.000000                       2.380000
# 50%    150000.500000      39.000000                       4.260000
# 75%    225000.250000      52.000000                       6.130000
# max    300000.000000      65.000000                       8.000000
#
#        Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# count                   300000.000000                300000.000000
# mean                         5.244080                     3.000143
# std                          2.741804                     1.413682
# min                          0.500000                     1.000000
# ...

# %% [markdown]
# # Answer: By loading the dataset and displaying its some of the major components, I can the results as:
# The dataset contains the social media data from YouTube, tiktok and facebook of different countries like Germany, India and many other.
# Also, it has various columns like age, usage time, daily entertainment time, platforms used, messaging rate, video, gaming, income, internet speed, monthly income, music listening time, time spent, news time, ads, and monthly expenditure. There are around 300000 numbers of data in total.
# In the above table of the data description it show the mean of each column, std, min and max of each columns in the dataset.

# %% [markdown]
# # Task 3: A note on how the data de-identifies or otherwise protects the users' when making the data available for public consumption.
# The dataset I have chosen ensures the users privacy and personal data. The dataset does not contain user name, user email, user phone and other personal information which proves that the dataset creator has removed those fields before making it publicly available. Also, instead of giving the original user id, it has given some random user id which shows the user's privacy and personal data is protected.

# %% [markdown]
# # Task 4: A note on how the data could be exploited otherwise:
# While de-identification has been followed on the dataset to protect user privacy, there is just so much risk involved in such data exploitation if not managed very responsibly. One major risk is re-identification through data linkage, or cross-referencing of the anonymized dataset with other publicly available data to make inferences on personal identities. Additionally, demographic and behavioral patterns are conceivable to design means of getting better advertising towards users or other manipulative schemes towards influencing behaviors of users for some purposes contrary to their good will. Given this dataset will comprise thoroughbred usage habits, these could, of course, be used for manipulative results for exploitation i.e. too much screen time, vulnerability to types of content that have been described in.
